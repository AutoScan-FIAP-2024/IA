# %%
# Importando bibliotecas
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import joblib
from sklearn.feature_extraction.text import TfidfVectorizer

# Definindo as listas de perguntas, categorias e sentimentos
perguntas = [
    "Como funciona o seguro de automóvel?", "O que é um seguro residencial?", "Qual a cobertura do seguro de saúde?",
    "Como posso acionar o seguro?", "O que não é coberto pelo seguro de automóvel?", "Quais são os tipos de seguros disponíveis?",
    "Como calcular o valor do prêmio do seguro?", "Quais documentos são necessários para contratar um seguro?",
    "O que fazer em caso de sinistro?", "Como funciona a indenização do seguro?", "Qual a diferença entre seguro e assistência?",
    "Como posso cancelar meu seguro?", "Quais são as penalidades para não pagamento do seguro?", "O que é a carência do seguro?",
    "Posso transferir meu seguro para outra pessoa?", "Como consultar a apólice do seguro?", "Quais são os benefícios do seguro residencial?",
    "O que é cobertura contra roubo?", "Como funciona a franquia do seguro?", "Quais são as principais seguradoras do Brasil?",
    "Como o perfil do motorista influencia no valor do seguro?", "O que é seguro de responsabilidade civil?", "Como funciona o seguro de vida?",
    "Posso fazer um seguro para veículos usados?", "O que é uma apólice de seguro?", "Como funciona o seguro para locação de veículos?",
    "Qual a diferença entre seguro e consórcio?", "O que é seguro de viagem?", "Como funciona o seguro de saúde para estrangeiros?",
    "Como é feito o cálculo do sinistro?", "O que é um corretor de seguros?", "Qual a validade do seguro?", "Como funciona o seguro de incêndio?",
    "O que é cobertura adicional?", "Como escolher um seguro que atenda minhas necessidades?", "O que é o seguro de garantia estendida?",
    "Como fazer uma reclamação no seguro?", "O que fazer se a seguradora negar o sinistro?", "Como funciona o seguro de automóveis para frotas?",
    "Quais são os requisitos para fazer um seguro de saúde?", "O que é o seguro de acidentes pessoais?", "Como a localização do veículo influencia no seguro?",
    "O que é um seguro de saúde coletivo?", "Como funciona o seguro de automóvel para motoristas de aplicativos?",
    "Qual a importância do seguro de vida?", "O que é um seguro de crédito?", "Como funciona o seguro de saúde individual?",
    "O que são cláusulas do seguro?", "Qual a diferença entre seguro e previdência?", "Como funciona o seguro de imóveis?",
    "Posso fazer um seguro para pessoas com doenças pré-existentes?", "Como funciona o seguro de viagem internacional?",
    "O que é um seguro de vida temporário?", "Como funciona o seguro para bicicletas?", "O que é um seguro contra desastres naturais?",
    "Quais são os direitos do consumidor em relação ao seguro?", "Como funciona o seguro para animais de estimação?",
    "O que é um seguro de responsabilidade civil profissional?", "Como funciona o seguro de saúde para dependentes?",
    "Qual a importância do seguro de automóvel?", "O que é uma exclusão de cobertura?", "Como funciona o seguro de crédito imobiliário?",
    "O que é um seguro de saúde familiar?", "Como funciona o seguro de incêndio em imóveis comerciais?",
    "O que é uma cláusula de rescisão?", "Como funciona o seguro de garantia para serviços?", "Qual a importância do seguro de vida para família?",
    "O que é um seguro de automóvel sem franquia?", "Como fazer a avaliação do valor do seguro?", "O que é o seguro de títulos?",
    "Como funciona o seguro de saúde em viagens?", "O que é um seguro de proteção financeira?", "Qual a importância do seguro de responsabilidade civil?",
    "Como funciona o seguro de automóvel para motoristas jovens?", "O que é um seguro de saúde corporativo?",
    "Quais são os riscos cobertos pelo seguro de propriedade?", "Como funciona o seguro de vida em grupo?",
    "O que é o seguro de acidentes de trabalho?", "Como funciona o seguro de responsabilidade civil para empresas?",
    "O que é um seguro de saúde para idosos?", "Como funciona o seguro de viagem nacional?", "O que é um seguro de danos a terceiros?",
    "Qual a diferença entre seguro de vida e previdência privada?", "Como funciona o seguro de saúde para recém-nascidos?",
    "O que é um seguro de automóvel com cobertura total?", "Como fazer um comparativo entre seguros?",
    "O que é um seguro de resgatabilidade?", "Como funciona o seguro para empresas de transporte?",
    "O que é um seguro de carga?", "Qual a importância do seguro para o patrimônio?",
    "Como funciona o seguro de automóvel para motoristas inexperientes?", "O que é um seguro de proteção ao crédito?",
    "Como funciona o seguro de saúde para gestantes?", "O que é um seguro de cancelamento de viagem?",
    "Como funciona o seguro para imóveis na planta?", "O que é um seguro de previdência empresarial?",
    "Como funciona o seguro de automóvel para pessoas com deficiência?", "O que é um seguro de garantia de aluguel?",
    "Como fazer a portabilidade de um seguro?", "O que é um seguro de responsabilidade civil para eventos?",
    "Como funciona o seguro de saúde para dependentes químicos?", "Qual a importância do seguro de vida em situações de emergência?",
    "O que é um seguro de automóvel com desconto por bom comportamento?", "Como funciona o seguro de saúde com reembolso?",
    "O que é um seguro de proteção a informações pessoais?", "Como funciona o seguro de automóvel para motoristas idosos?",
    "O que é um seguro de viagem para mochileiros?"
]

categorias = [
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura",
    "Cobertura", "Cobertura", "Cobertura", "Cobertura", "Cobertura"
]

sentimentos = [
    "Positivo", "Positivo", "Positivo", "Negativo", "Positivo",
    "Negativo", "Negativo", "Positivo", "Positivo", "Positivo",
    "Neutro", "Positivo", "Positivo", "Negativo", "Positivo",
    "Positivo", "Positivo", "Neutro", "Positivo", "Positivo",
    "Positivo", "Negativo", "Positivo", "Positivo", "Positivo",
    "Positivo", "Negativo", "Negativo", "Positivo", "Positivo",
    "Negativo", "Positivo", "Negativo", "Negativo", "Positivo",
    "Positivo", "Positivo", "Negativo", "Negativo", "Negativo",
    "Positivo", "Positivo", "Positivo", "Neutro", "Positivo",
    "Negativo", "Positivo", "Positivo", "Negativo", "Positivo",
    "Positivo", "Positivo", "Positivo", "Positivo", "Positivo",
    "Negativo", "Negativo", "Positivo", "Positivo", "Negativo",
    "Positivo", "Negativo", "Positivo", "Negativo", "Positivo",
    "Positivo", "Negativo", "Positivo", "Negativo", "Negativo",
    "Positivo", "Positivo", "Negativo", "Negativo", "Positivo",
    "Positivo", "Positivo", "Negativo", "Positivo", "Negativo",
    "Positivo", "Positivo", "Negativo", "Positivo", "Positivo",
    "Positivo", "Negativo", "Positivo", "Negativo", "Positivo",
    "Positivo", "Negativo", "Negativo", "Positivo", "Positivo",
    "Positivo", "Positivo", "Positivo", "Negativo", "Positivo",
    "Negativo", "Positivo", "Positivo", "Negativo", "Positivo",
    "Positivo", "Positivo", "Negativo", "Positivo", "Negativo"
]

# Ajustando as listas para que tenham o mesmo comprimento (110)
perguntas = perguntas[:100]  # Mantém os primeiros 110 elementos
categorias = categorias[:100]  # Mantém os primeiros 110 elementos
sentimentos = sentimentos[:100]  # Mantém os primeiros 110 elementos

# Criando o DataFrame
data = {
    'Pergunta': perguntas,
    'Categoria': categorias,
    'Sentimento': sentimentos
}

# Criando o DataFrame
df = pd.DataFrame(data)

# Convertendo rótulos em numéricos
df['Sentimento'] = df['Sentimento'].map({'Positivo': 1, 'Negativo': 0, 'Neutro': 2})

# Separando variáveis independentes e dependentes
X = df['Pergunta']
y = df['Sentimento']

# Transformando texto em características numéricas
vectorizer = TfidfVectorizer()
X_vectorized = vectorizer.fit_transform(X)

# Dividindo o conjunto de dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X_vectorized, y, test_size=0.2, random_state=42)

# Criando o modelo
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Avaliando o modelo
y_pred = model.predict(X_test)

# Gerando o relatório de classificação
report = classification_report(y_test, y_pred, zero_division=0)
print("Relatório de Classificação:\n", report)

# Salvando o modelo treinado
joblib.dump(model, 'modelo_classificacao.joblib')
joblib.dump(vectorizer, 'vectorizer.joblib')
# Out:
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#            0       0.25      0.17      0.20         6
#            1       0.69      0.85      0.76        13
#            2       0.00      0.00      0.00         1
#
#     accuracy                           0.60        20
#    macro avg       0.31      0.34      0.32        20
# weighted avg       0.52      0.60      0.55        20
# ['vectorizer.joblib']
